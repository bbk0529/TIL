# %%
def file2mat(filename) :
    import numpy as np
    f=open(filename)
    mat=[]
    ans=[]
    for i in f.readlines() :
        curLine=i.split('\t')
        a = [float(x) for x in curLine[:-1]]
        mat.append(a)
        ans.append(int(curLine[-1]))
        nummat=np.array(mat)
        #returnMatrix=(nummat - nummat.min(0)) / (nummat.max(0) - nummat.min(0)) #normalization
    return nummat, ans

def norm (mat) :
    returnMatrix=(mat - mat.min(0)) / (mat.max(0) - mat.min(0)) #normalization
    return returnMatrix

# %%
mat, ans = file2mat('datingTestSet2.txt') #datatingTestset - label : texts, datingtestset2 - label : number

# %%
returnMat = norm(mat)

# %%
returnMat
# Out:
# array([[ 0.44832535,  0.39805139,  0.56233353],
#        [ 0.15873259,  0.34195467,  0.98724416],
#        [ 0.28542943,  0.06892523,  0.47449629],
#        ...,
#        [ 0.29115949,  0.50910294,  0.51079493],
#        [ 0.52711097,  0.43665451,  0.4290048 ],
#        [ 0.47940793,  0.3768091 ,  0.78571804]])

# %%
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
fig=plt.figure()
ax=fig.add_subplot(111)
ax.scatter(mat[:,0], mat[:,1], 10*np.array(ans), 10*np.array(ans) )

# %%
fig=plt.figure()
ax=fig.add_subplot(111)
ax.scatter(mat[:,0], mat[:,2], 10*np.array(ans), 10*np.array(ans))

# %%
returnMat.shape[0]
# Out:
# 1000

# %%
result={3: 'largeDoses', 2: 'smallDoses', 1: 'didntLike'}

# %%
import imp
imp.reload(kNN)

number=0
ratio=0.1
testNum = int(returnMat.shape[0] * ratio)
for i in range(testNum) : 
    classfyedResult=kNN.classfy0(returnMat[i, :], returnMat[testNum:, :], ans[testNum:, :], 3)
    if classfyedResult == ans[i] : number+=1
    print (result[classfyedResult], '   ', result[ans[i]])
print(number / testNum)
# Out:
# <module 'kNN' from '/home/ubuntu/workspace/TIL/MachineLearning/kNN.py'>
#  It seems highly:  1
# didntLike     largeDoses
#
#  It seems highly:  3
# largeDoses     smallDoses
#
#  It seems highly:  1
# didntLike     didntLike
#
#  It seems highly:  2
# smallDoses     didntLike
#
#  It seems highly:  2
# smallDoses     didntLike
#
#  It seems highly:  1
# didntLike     didntLike
#
#  It seems highly:  2
# smallDoses     largeDoses
#
#  It seems highly:  1
# didntLike     largeDoses
#
#  It seems highly:  1
# didntLike     didntLike
#
#  It seems highly:  2
# smallDoses     largeDoses
#
#  It seems highly:  1
# didntLike     didntLike
#
#  It seems highly:  2
# smallDoses     didntLike
#
#  It seems highly:  1
# didntLike     smallDoses
#
#  It seems highly:  3
# largeDoses     didntLike
#
#  It seems highly:  2
# smallDoses     didntLike
#
#  It seems highly:  2
# smallDoses     didntLike
#
#  It seems highly:  3
# largeDoses     didntLike
#
#  It seems highly:  2
# smallDoses     didntLike
#
#  It seems highly:  2
# smallDoses     smallDoses
#
#  It seems highly:  3
# largeDoses     largeDoses
#
#  It seems highly:  1
# didntLike     smallDoses
#
#  It seems highly:  3
# largeDoses     didntLike
#
#  It seems highly:  3
# largeDoses     smallDoses
#
#  It seems highly:  1
# didntLike     largeDoses
#
#  It seems highly:  3
# largeDoses     smallDoses
#
#  It seems highly:  2
# smallDoses     largeDoses
#
#  It seems highly:  1
# didntLike     smallDoses
#
#  It seems highly:  1
# didntLike     largeDoses
#
#  It seems highly:  1
# didntLike     smallDoses
#
#  It seems highly:  1
# didntLike     didntLike
#
#  It seems highly:  1
# didntLike     largeDoses
#
#  It seems highly:  3
# largeDoses     didntLike
#
#  It seems highly:  1
# didntLike     largeDoses
#
#  It seems highly:  3
# largeDoses     didntLike
#
#  It seems highly:  2
# smallDoses     smallDoses
#
#  It seems highly:  1
# didntLike     didntLike
#
#  It seems highly:  1
# didntLike     didntLike
#
#  It seems highly:  1
# didntLike     smallDoses
#
#  It seems highly:  1
# didntLike     largeDoses
#
#  It seems highly:  1
# didntLike     largeDoses
#
#  It seems highly:  2
# smallDoses     didntLike
#
#  It seems highly:  1
# didntLike     smallDoses
#
#  It seems highly:  1
# didntLike     largeDoses
#
#  It seems highly:  3
# largeDoses     largeDoses
#
#  It seems highly:  1
# didntLike     largeDoses
#
#  It seems highly:  3
# largeDoses     didntLike
#
#  It seems highly:  3
# largeDoses     didntLike
#
#  It seems highly:  1
# didntLike     didntLike
#
#  It seems highly:  3
# largeDoses     didntLike
#
#  It seems highly:  3
# largeDoses     smallDoses
#
#  It seems highly:  2
# smallDoses     smallDoses
#
#  It seems highly:  2
# smallDoses     didntLike
#
#  It seems highly:  1
# didntLike     largeDoses
#
#  It seems highly:  3
# largeDoses     smallDoses
#
#  It seems highly:  1
# didntLike     smallDoses
#
#  It seems highly:  1
# didntLike     smallDoses
#
#  It seems highly:  3
# largeDoses     smallDoses
#
#  It seems highly:  2
# smallDoses     largeDoses
#
#  It seems highly:  1
# didntLike     didntLike
#
#  It seems highly:  2
# smallDoses     smallDoses
#
#  It seems highly:  2
# smallDoses     didntLike
#
#  It seems highly:  3
# largeDoses     smallDoses
#
#  It seems highly:  3
# largeDoses     smallDoses
#
#  It seems highly:  2
# smallDoses     smallDoses
#
#  It seems highly:  1
# didntLike     smallDoses
#
#  It seems highly:  2
# smallDoses     smallDoses
#
#  It seems highly:  2
# smallDoses     largeDoses
#
#  It seems highly:  3
# largeDoses     smallDoses
#
#  It seems highly:  2
# smallDoses     largeDoses
#
#  It seems highly:  1
# didntLike     didntLike
#
#  It seems highly:  1
# didntLike     smallDoses
#
#  It seems highly:  2
# smallDoses     largeDoses
#
#  It seems highly:  3
# largeDoses     smallDoses
#
#  It seems highly:  3
# largeDoses     smallDoses
#
#  It seems highly:  1
# didntLike     didntLike
#
#  It seems highly:  1
# didntLike     largeDoses
#
#  It seems highly:  1
# didntLike     didntLike
#
#  It seems highly:  1
# didntLike     didntLike
#
#  It seems highly:  1
# didntLike     largeDoses
#
#  It seems highly:  1
# didntLike     largeDoses
#
#  It seems highly:  1
# didntLike     didntLike
#
#  It seems highly:  2
# smallDoses     smallDoses
#
#  It seems highly:  2
# smallDoses     largeDoses
#
#  It seems highly:  2
# smallDoses     didntLike
#
#  It seems highly:  1
# didntLike     largeDoses
#
#  It seems highly:  1
# didntLike     didntLike
#
#  It seems highly:  1
# didntLike     smallDoses
#
#  It seems highly:  1
# didntLike     smallDoses
#
#  It seems highly:  1
# didntLike     didntLike
#
#  It seems highly:  1
# didntLike     didntLike
#
#  It seems highly:  3
# largeDoses     largeDoses
#
#  It seems highly:  3
# largeDoses     largeDoses
#
#  It seems highly:  1
# didntLike     didntLike
#
#  It seems highly:  1
# didntLike     smallDoses
#
#  It seems highly:  2
# smallDoses     didntLike
#
#  It seems highly:  1
# didntLike     largeDoses
#
#  It seems highly:  1
# didntLike     largeDoses
#
#  It seems highly:  1
# didntLike     smallDoses
#
#  It seems highly:  1
# didntLike     didntLike
#
#  It seems highly:  2
# smallDoses     didntLike
# 0.3

# %%
# Out:
# label : 3 count : 3
#
#  It seems highly:  3
# {3: 3}
